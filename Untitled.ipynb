# %%
import openpyxl
import pandas as pd

# %%
file = pd.read_excel('test_table.xlsx',
                     names = ['대상업무','업무량','부담금'],
                     header = None)

# %%
file = pd.DataFrame(file).dropna(subset=["대상업무"])

# %%
print(file.head())
# Out:
#                        대상업무  업무량        부담금
# 0         Ⅰ.한국원자력안전기술원 위탁업무  NaN        NaN
# 1               1. 한국원자력연구원  NaN        NaN
# 2                   가. 정기검사  NaN        NaN
# 3                1) 연구용원자로   635  252857000
# 4    2) 사용후핵연료 처리시설(매2년 주기)  120   47784000

# %%
file
# Out:
#                                                   대상업무  업무량        부담금
# 0                                    Ⅰ.한국원자력안전기술원 위탁업무  NaN        NaN
# 1                                          1. 한국원자력연구원  NaN        NaN
# 2                                              가. 정기검사  NaN        NaN
# 3                                           1) 연구용원자로   635  252857000
# 4                               2) 사용후핵연료 처리시설(매2년 주기)  120   47784000
# ..                                                 ...  ...        ...
# 562     1) 법 제98조제2항 및 제4항에 따른 검사 및 시료수거를 위한 인력 및 기...   　-         　-
# 563       2) 법 제98조 제6항에 따른 국제규제물자의 이동을 확인하기 위한 장치의 설치   　-         　-
# 564                            바. 법 제111조제1항제9호에 따른 업무  NaN        NaN
# 565                         1) 법 제106조제3항 원자력통제에 관한 교육   　-         　-
# 566                                                합 계    9    2830000
#
# [562 rows x 3 columns]

# %%
def is_ins(cell) :
    if ('Ⅰ' in cell) : return True
    elif ('Ⅱ' in cell) : return True
    elif ('Ⅲ' in cell) : return True
    else : return False

def def_ins(cell) :
    if('한국원자력안전기술' in cell) : return 'KINS'
    elif('한국원자력통제기술' in cell) : return 'KINAC'
    else : return 'UI'
    
def blank_counter(cell):
    blank = len(cell) - len(cell.lstrip())
    return blank

def table_maker(df) :

    for i in df.index :
        if is_ins(df['대상업무'][i]) :
            ins = def_ins(df['대상업무'][i])
        else : blank_counter(df['대상업무'][i])

# %%
table_maker(file)
# Out:
# KINS
# 0
# 1
# 2
# 2
# 2
# 2
# 2
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 1
# 1
# 2
# 2
# 1
# 2
# 2
# 2
# 2
# 1
# 2
# 1
# 1
# 0
# 0
# 1
# 1
# 1
# 1
# 0
# 0
# 1
# 2
# 3
# 4
# 6
# 8
# 8
# 6
# 6
# 4
# 6
# 8
# 8
# 8
# 8
# 8
# 8
# 6
# 6
# 6
# 7
# 7
# 6
# 7
# 7
# 6
# 7
# 7
# 4
# 6
# 7
# 7
# 7
# 5
# 7
# 7
# 7
# 5
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 4
# 4
# 4
# 4
# 4
# 3
# 4
# 5
# 7
# 7
# 7
# 7
# 7
# 5
# 5
# 5
# 4
# 5
# 7
# 7
# 7
# 7
# 7
# 7
# 5
# 5
# 5
# 6
# 6
# 5
# 6
# 6
# 5
# 6
# 6
# 4
# 5
# 7
# 7
# 7
# 5
# 7
# 7
# 7
# 5
# 7
# 7
# 7
# 7
# 7
# 7
# 7
#